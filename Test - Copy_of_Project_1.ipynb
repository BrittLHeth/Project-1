# %% [markdown]
# <a href="https://colab.research.google.com/github/BrittLHeth/Project-1/blob/master/Test%20-%20Copy_of_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
parking_meter_df = pd.read_csv("https://raw.githubusercontent.com/BrittLHeth/Project-1/master/parking_meters.csv")
parking_meter_df.head()
# Out:
#    ZONE SD_TRANS_ALLMETERS_P_AREA  ...   CARRIER      WARRANTY_EXPIRY
# 0   COL            Logan St - COL  ...  T-Mobile  2012-06-20 00:00:00
# 1   COL        E Colfax Ave - COL  ...  T-Mobile  2011-02-24 00:00:00
# 2   CCC           N Broadway -CCC  ...   Verizon  2017-12-14 00:00:00
# 3  CAPN         E 17th Ave - CAPN  ...  T-Mobile  2011-11-08 00:00:00
# 4   CCC          W 12th Ave - CCC  ...  T-Mobile  2011-03-10 00:00:00
#
# [5 rows x 37 columns]

# %%
# parking meters by zone 
# Drop bad data points - yet to add 

parking_meter_df["ZONE"].value_counts()
# Out:
# OVN          2995
# CCC           600
# CCN           579
# BRD           435
# CAPS          419
# CAPN          261
# COL           235
# AUR           190
# MED           153
# DUV           124
# RAV            77
# FIV            74
# Night           1
# Test Zone       1
# Name: ZONE, dtype: int64

# %% [markdown]
# # drop
